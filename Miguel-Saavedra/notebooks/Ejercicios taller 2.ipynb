# %% [markdown]
# # en primer lugar cargo la librerias para importar datafrem y a que load_boston , no se puede descargar como objeto en el momento por temas eticos salio de sklearn

# %%
import pandas as pd
import numpy as np
load_boston = pd.read_csv('/Users/m1pro/Documents/inteligencia artificial/Repositorio/Miguel-Saavedra/data/Boston /boston_house_prices (2).csv')

# %% [markdown]
# #posteriromente importo las librerias necesarias pora crear un modelo de entrenamiento y  usar herramientas para escalar datos

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# %% [markdown]
# # cargo mis datos para  evaluar que este correctemaente importada

# %%
load_boston
# Out:
#          506  13 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6  \
# 0       CRIM  ZN      INDUS       CHAS        NOX         RM        AGE
# 1    0.00632  18       2.31          0      0.538      6.575       65.2
# 2    0.02731   0       7.07          0      0.469      6.421       78.9
# 3    0.02729   0       7.07          0      0.469      7.185       61.1
# 4    0.03237   0       2.18          0      0.458      6.998       45.8
# ..       ...  ..        ...        ...        ...        ...        ...
# 502  0.06263   0      11.93          0      0.573      6.593       69.1
# 503  0.04527   0      11.93          0      0.573       6.12       76.7
# 504  0.06076   0      11.93          0      0.573      6.976         91
# 505  0.10959   0      11.93          0      0.573      6.794       89.3
# 506  0.04741   0      11.93          0      0.573       6.03       80.8
#
#     Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10 Unnamed: 11 Unnamed: 12  \
# ...

# %%
boston = load_boston

# %% [markdown]
# #luego hago una variacion ya que no dipongo la data para  crear  x  objetc y target

# %%
boston = load_boston
X, y = boston.iloc[:, :-1], boston.iloc[:, -1]

# %% [markdown]
# # prefiero hacer un split con el 50% de la muestra , asi que ajusto el codigo

# %%
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)

# %%
print(x_train.shape, x_test.shape)
# Out:
# (253, 13) (254, 13)

# %%
x_train.head()
# Out:
#          506  13 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6  \
# 133  0.59005   0      21.89          0      0.624      6.372       97.9
# 33   1.38799   0       8.14          0      0.538       5.95         82
# 482  5.70818   0       18.1          0      0.532       6.75       74.9
# 44   0.15936   0       6.91          0      0.448      6.211        6.5
# 61   0.14932  25       5.13          0      0.453      5.741       66.2
#
#     Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10 Unnamed: 11 Unnamed: 12
# 133     2.3274          4        437        21.2      385.76       11.12
# 33        3.99          4        307          21       232.6       27.71
# 482     3.3317         24        666        20.2      393.07        7.74
# 44      5.7209          3        233        17.9      394.46        7.44
# 61      7.2254          8        284        19.7      395.11       13.15

# %% [markdown]
# # inicio el proceso de escalamento con el metodo standard

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
# One-hot encode the categorical variables
x_train_encoded = pd.get_dummies(x_train)
x_test_encoded = pd.get_dummies(x_test)

# Fit the scaler on the encoded data
scaler.fit(x_train_encoded)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/lt/mjvbj3x57f1f2jwnkwqyyqw40000gn/T/ipykernel_14800/987800673.py in ?()
# ----> 1 scaler.fit(x_train)
#
# ~/Documents/inteligencia artificial/Repositorio/Miguel-Saavedra/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_data.py in ?(self, X, y, sample_weight)
#     872             Fitted scaler.
#     873         """
#     874         # Reset internal state before fitting
#     875         self._reset()
# --> 876         return self.partial_fit(X, y, sample_weight)
#
# ~/Documents/inteligencia artificial/Repositorio/Miguel-Saavedra/.venv/lib/python3.12/site-packages/sklearn/base.py in ?(estimator, *args, **kwargs)
#    1347                 skip_parameter_validation=(
#    1348                     prefer_skip_nested_validation or global_skip_validation
#    1349                 )
#    1350             ):
# ...
